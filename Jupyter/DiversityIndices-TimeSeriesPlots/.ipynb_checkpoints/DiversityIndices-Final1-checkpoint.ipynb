# %%
# %matplotlib notebook

from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

#import DiversityIndicesBiblio
from DiversityIndicesBiblio import *

# %%
def PlotRichness(Tempo,Virus,Bacterias,t1,t2):
    
    T = []
    B = []    
    V = []
    
    for t in range(t1-1,t2):
        T.append(float(Tempo[t]))
        V.append(float(Virus[t]))
        B.append(float(Bacterias[t]))
    
    figure(dpi= 130)

    plot(T, V, '-', label='Virus')
    plot(T, B, '-', label='Bacteria')
    grid(True)
    legend(loc='upper left')
    title('Diversity Indices ')
    xlabel('time $t$ (hr)')
    ylabel('Richness  $S$')
    
def ShannonIndex(Tempo,Virus,Bacterias,t1,t2):
    
    T = []
    B = []    
    V = []
    
    for t in range(t1-1,t2):
        T.append(float(Tempo[t]))
        B.append(float(Bacterias[t]))
        V.append(float(Virus[t]))
    
    figure(dpi= 130)
    plot(T, V, label='Virus')
    plot(T, B, 'r', label='Bacteria')
    grid(True)
    legend(loc='upper left')
    xlabel('time $t$ (hr)')
    ylabel('ShannonIndex  $H$')
    
def PlotEvenness(Tempo,Virus,Bacterias,t1,t2):
    
    T = []
    B = []    
    V = []
    
    for t in range(t1-1,t2):
        T.append(float(Tempo[t]))
        V.append(float(Virus[t]))
        B.append(float(Bacterias[t]))
    
    figure(dpi= 130)
    
    plot(T, V, 'b', label='Virus')
    plot(T, B, 'r', label='Bacteria')
    grid(True)
    legend(loc='upper left')
    xlabel('time $t$ (hr)')
    ylabel('Evenness  $E_H$')

# %% [markdown]
# #  <center>############### Chosing DATA #################</center>

# %% [markdown]
# ##  <center>Low Mutation Rate</center>

# %% [markdown]
# $\mu = 1x10^{-7}$ <br />
# 1 Initial Virus Strain  ("Cold Start")

# %%
virus_file = "../DATA/1_Low-MutRate/ColdStart/mu1e-7_initialDiffDp1_S10P15_R-12499_data-phage.txt"
bacteria_file = "../DATA/1_Low-MutRate/ColdStart/mu1e-7_initialDiffDp1_S10P15_R-12499_data-bact.txt"

# %% [markdown]
# $\mu = 1x10^{-7}$ <br />
# 10 Initial Virus Strain  ("Hot Start")

# %%
virus_file = "../DATA/1_Low-MutRate/HotStart/mu1e-7_initialDiffDp10_S10P15_R-1987_data-phage.txt"
bacteria_file = "../DATA/1_Low-MutRate/HotStart/mu1e-7_initialDiffDp10_S10P15_R-1987_data-bact.txt"

# %% [markdown]
# ##  <center>High Mutation Rate</center>

# %% [markdown]
# $\mu = 5x10^{-7}$ <br />
# 1 Initial Virus Strain  ("Cold Start")

# %%
virus_file = "../DATA/2_Hi-MutRate/ColdStart/mu5e-7_initialDiffDp1_S10P15_R-5364_data-phage.txt"
bacteria_file = "../DATA/2_Hi-MutRate/ColdStart/mu5e-7_initialDiffDp1_S10P15_R-5364_data-bact.txt"

# %% [markdown]
# $\mu = 5x10^{-7}$ <br />
# 10 Initial Virus Strain  ("Hot Start")

# %%
virus_file = "../DATA/2_Hi-MutRate/HotStart/mu5e-7_initialDiffDp10_S10P15_R-13073_data-phage.txt"
bacteria_file = "../DATA/2_Hi-MutRate/HotStart/mu5e-7_initialDiffDp10_S10P15_R-13073_data-bact.txt"

# %%
#Tv,Rv,Hv,Ev = DiversityIndices(virus_file)
#Tb,Rb,Hb,Eb = DiversityIndices(bacteria_file)
# Out:
# DiversityIndicesBiblio.py:62: RuntimeWarning: invalid value encountered in double_scalars
#   E = (H/(mth.log(R)))
# DiversityIndicesBiblio.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   E = (H/(mth.log(R)))

# %% [markdown]
# #  <center>############### Chosing Time Range #################</center>

# %%
t1, t2 = 1000, 2300

# %%
PlotRichness(Tv,Rv,Rb,t1,t2)
# Out:
# <img src="data:image/png;base64,..." width="832">

# %%
ShannonIndex(Tv,Hv,Hb,t1,t2)
# Out:
# <img src="data:image/png;base64,..." width="832">

# %%
PlotEvenness(Tv,Ev,Eb,t1,t2)
# Out:
# <img src="data:image/png;base64,..." width="832">
